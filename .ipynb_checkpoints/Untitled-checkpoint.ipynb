# %%
pwd
# Out:
# '/root/autodl-tmp/00_github/Chinese Character Checking with Faked and Misspelled Characters'

# %%
## photo 处理
from PIL import Image
img1=Image.open("methods.PNG")
img2=Image.open("task1.PNG")
img3=Image.open("effect.PNG")

img1.size
# Out:
# (1527, 781)

# %%
img2.size
# Out:
# (464, 324)

# %%
## 01 基于resize
def resize_rate(img,num):
    return img.resize((num, int(img.size[1] * num / img.size[0])))
resize_rate(img1,800).save("methods_1.PNG")

# %%
img.

# %%
resize_rate(img2,350).save("task1_1.PNG")

# %%
resize_rate(img2,200)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x139>

# %%
resize_rate(img3,600).save("effect_1.PNG")
